# %%
# Usaremos la api de tmdb

import requests

url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NmY0ZmZlODYxMGQ0NTI4OTYwYzMwNzJjYjJkMjEwOCIsIm5iZiI6MTc3NjU5MDI3Ni42OTI5OTk4LCJzdWIiOiI2OWU0OWRjNDlkNzcyYzkyYTE5NDBiNzYiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.OyxOsN-7AU_LmwgfyxEgKiEeXAtwX2PiH-IMjzhmah0"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true}

# %%
import requests

url = "https://api.themoviedb.org/3/search/movie?query=spiderman&include_adult=true&language=es-ES&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NmY0ZmZlODYxMGQ0NTI4OTYwYzMwNzJjYjJkMjEwOCIsIm5iZiI6MTc3NjU5MDI3Ni42OTI5OTk4LCJzdWIiOiI2OWU0OWRjNDlkNzcyYzkyYTE5NDBiNzYiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.OyxOsN-7AU_LmwgfyxEgKiEeXAtwX2PiH-IMjzhmah0"
}

response = requests.get(url, headers=headers)

# %%
processed_response = response.json()["results"]

# %%
import pandas as pd

# %%
response_df = pd.DataFrame(processed_response)
response_df.head()
# Out:
#    adult                     backdrop_path          genre_ids      id  \
# 0  False  /zQ8AxTPiCiS5nnwXpwTBPBHSaa5.jpg          [28, 878]     557
# 1  False  /vjMvFSmGUxEtqVdaZgvFee9XkZl.jpg      [878, 28, 12]  969681
# 2  False  /34jW8LvjRplM8Pv06cBFDpLlenR.jpg      [28, 12, 878]  429617
# 3  False  /tPpYGm2mVecue7Bk3gNVoSPA5qn.jpg      [28, 12, 878]  315635
# 4  False  /9xfDWXAUbFXQK585JvByT5pEAhe.jpg  [16, 28, 12, 878]  569094
#
#   original_language                       original_title  \
# 0                en                           Spider-Man
# 1                en            Spider-Man: Brand New Day
# 2                en            Spider-Man: Far From Home
# 3                en               Spider-Man: Homecoming
# 4                en  Spider-Man: Across the Spider-Verse
#
#                                             overview  popularity  \
# 0  Peter Parker es un joven y tímido estudiante q...     22.9414
# 1  Han pasado cuatro años desde los acontecimient...     31.7253
# 2  Peter Parker decide irse junto a MJ, Ned y el ...     21.7688
# 3  Peter Parker comienza a experimentar su recién...     30.1907
# 4  Tras reencontrarse con Gwen Stacy, el amigable...     21.9774
#
#                         poster_path release_date  \
# 0  /bCDaKZLRkrVVtPNyHxUfKvepW1N.jpg   2002-05-01
# 1  /ct7rSLY6OlQBETxQDzINzkhYIO2.jpg   2026-07-29
# 2  /o59zDVJDIehGcWZsMUGU5SN0V0D.jpg   2019-06-28
# 3  /yJfPC6pjSJ5VOsVyXhx5PXBe0mR.jpg   2017-07-05
# 4   /37WcNMgNOMxdhT87MFl7tq7FM1.jpg   2023-05-31
#
#                                 title  video  vote_average  vote_count
# 0                          Spider-Man  False         7.324       20514
# 1            Spider-Man: Un nuevo día  False         0.000           0
# 2           Spider-Man: Lejos de casa  False         7.396       16835
# 3              Spider-Man: Homecoming  False         7.331       23029
# 4  Spider-Man: Cruzando el Multiverso  False         8.332        8456

# %%
response_df[["title", "overview", "release_date", "vote_average", "vote_count", "poster_path", "backdrop_path"]].to_json(orient="records")
# Out:
# '[{"title":"Spider-Man","overview":"Peter Parker es un joven y t\\u00edmido estudiante que vive con su t\\u00eda May y su t\\u00edo Ben desde la muerte de sus padres. Un d\\u00eda es mordido por una ara\\u00f1a que ha sido modificada gen\\u00e9ticamente, descubriendo al d\\u00eda siguiente que posee unos poderes poco habituales: tiene la fuerza y agilidad de una ara\\u00f1a.","release_date":"2002-05-01","vote_average":7.324,"vote_count":20511,"poster_path":"\\/bCDaKZLRkrVVtPNyHxUfKvepW1N.jpg","backdrop_path":"\\/zQ8AxTPiCiS5nnwXpwTBPBHSaa5.jpg"},{"title":"Spider-Man: Un nuevo d\\u00eda","overview":"Han pasado cuatro a\\u00f1os desde los acontecimientos de No Way Home, y Peter Parker ahora es un adulto que vive completamente solo, ha desaparecido voluntariamente de las vidas y recuerdos de quienes ama. Combatiendo el crimen en una Nueva York que ya no conoce su nombre, se ha dedicado por completo a proteger su ciudad, pero a medida que aumentan las exigencias sobre \\u00e9l, la presi\\u00f3n desencadena una evoluci\\u00f3n f\\u00edsica que amenaza su existencia, al mismo tiempo que un extra\\u00f1o nuevo patr\\u00f3n de cr\\u00edmenes da lugar a una de las amenazas m\\u00e1s poderosas a las que se ha enfrentado.","release_date":"2026-07-29","vote_average":0.0,"vote_count":0,"poster_path":"\\/ct7rSLY6OlQBETxQDzINzkhYIO2.jpg","backdrop_path":"\\/vjMvFSmGUxEtqVdaZgvFee9XkZl.jpg"},{"title":"Spider-Man: Lejos de casa","overview":"Peter Parker decide irse junto a MJ, Ned y el resto de sus amigos a pasar unas vacaciones a Europa. Sin embargo, el plan de Parker por dejar de lado sus superpoderes durante unas semanas se ven truncados cuando Nick Fury contacta con \\u00e9l para solicitarle ayuda para frenar el ataque de unas criaturas elementales que est\\u00e1n causando el caos en el continente. En ese momento, Parker vuelve a ponerse el traje de Spider-Man para cumplir con su labor.","release_date":"2019-06-28","vote_average":7.397,"vote_count":16834,"poster_path":"\\/o59zDVJDIehGcWZsMUGU5SN0V0D.jpg","backdrop_path":"\\/34jW8LvjRplM8Pv06cBFDpLlenR.jpg"},{"title":"Spider-Man: Homecoming","overview":"Peter Parker comienza a experimentar su reci\\u00e9n descubierta identidad como el superh\\u00e9roe Spider-Man. Despu\\u00e9s de la experiencia vivida con los Vengadores, Peter regresa a casa, donde vive con su t\\u00eda. Bajo la atenta mirada de su mentor Tony Stark, Peter intenta mantener una vida normal como cualquier joven de su edad, pero interrumpe en su rutina diaria el nuevo villano Vulture y, con \\u00e9l, lo m\\u00e1s importante de la vida de Peter comenzar\\u00e1 a verse amenazado.","release_date":"2017-07-05","vote_average":7.331,"vote_count":23029,"poster_path":"\\/yJfPC6pjSJ5VOsVyXhx5PXBe0mR.jpg","backdrop_path":"\\/tPpYGm2mVecue7Bk3gNVoSPA5qn.jpg"},{"title":"Spider-Man: Cruzando el Multiverso","overview":"Tras reencontrarse con Gwen Stacy, el amigable vecindario de Spider-Man de Brooklyn al completo es catapultado a trav\\u00e9s del Multiverso, donde se encuentra con un equipo de Spidermans encargados de proteger su propia existencia. Pero cuando los h\\u00e9roes se enfrentan sobre c\\u00f3mo manejar una nueva amenaza, Miles se encuentra enfrentado a las otras Ara\\u00f1as y debe redefinir lo que significa ser un h\\u00e9roe para poder salvar a la gente que m\\u00e1s quiere.","release_date":"2023-05-31","vote_average":8.332,"vote_count":8456,"poster_path":"\\/37WcNMgNOMxdhT87MFl7tq7FM1.jpg","backdrop_path":"\\/9xfDWXAUbFXQK585JvByT5pEAhe.jpg"},{"title":"Spider-Man: un nuevo universo","overview":"En un universo paralelo donde Peter Parker ha muerto, un joven de secundaria llamado Miles Morales es el nuevo Spider-Man. Sin embargo, cuando el l\\u00edder mafioso Wilson Fisk construye el \'Super Colisionador\' trae a una versi\\u00f3n alternativa de Peter Parker que tratar\\u00e1 de ense\\u00f1ar a Miles como ser un mejor Spider-Man. Pero no ser\\u00e1 el \\u00fanico Spider Man en entrar a este universo:  cuatro versiones alternati ...

# %%
poster_path = "/bCDaKZLRkrVVtPNyHxUfKvepW1N.jpg"

# URL completa del poster
poster_url = f"https://image.tmdb.org/t/p/w500{poster_path}"
print(poster_url)
# Out:
# https://image.tmdb.org/t/p/w500/bCDaKZLRkrVVtPNyHxUfKvepW1N.jpg

# %%
backdrop_path = "/zQ8AxTPiCiS5nnwXpwTBPBHSaa5.jpg"

# URL completa del backdrop
backdrop_url = f"https://image.tmdb.org/t/p/w500{backdrop_path}"
print(backdrop_url)
# Out:
# https://image.tmdb.org/t/p/w500/zQ8AxTPiCiS5nnwXpwTBPBHSaa5.jpg
