# %%
import os

# %%
dir = "../../torrents/"
os.listdir(dir)
# Out:
# ['170756-Spider-Man-No-Way-Home--BDremux.torrent',
#  'Salvar_al_soldado_ryan_HDRip2_65gb.torrent']

# %%
conn_info = dict(
    host="localhost",
    port=8080,
    username="admin",
    password="316440",
)
